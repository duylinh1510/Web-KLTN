# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
PROJECT_DIR = '/content/drive/MyDrive/fgnn_oracle'
os.chdir(PROJECT_DIR)
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /content/drive/MyDrive/fgnn_oracle

# %%
# !sudo apt-get install -y zstd --quiet
# !pip install torch torch_geometric pandas numpy scikit-learn requests --quiet
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 2s (335 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package zstd.
# ...

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# Start server + pull model
import subprocess, time, requests

subprocess.Popen(
    ["/usr/local/bin/ollama", "serve"],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.DEVNULL
)
time.sleep(5)

r = requests.get("http://localhost:11434")
print(f"Server: {r.status_code}")

# !ollama pull llama3.2:3b
# Out:
# Server: 200

# %%
# !ollama list
# Out:
# NAME           ID              SIZE      MODIFIED
# llama3.2:3b    a80c4f17acd5    2.0 GB    11 seconds ago

# %%
# !python pipeline.py \
    --csv_path fraud_oracle.csv \
    --target_label FraudFound_P \
    --ollama_model llama3.2:3b
# Out:
# ...
# [PIPELINE] fraud_oracle.csv
# ...
#   max_group_size  : 500
#
# [1/5] Đọc CSV...
#   Shape: (15420, 33)
#
# [2/5] Phân tích schema...
#   -> Đang nhờ LLM suy luận schema...
#
#   Schema đã phân tích:
#     node_id       : None
#     relation_cols : ['Make', 'AccidentArea', 'Sex', 'MaritalStatus']
#     feature       : ['Month', 'WeekOfMonth', 'DayOfWeek', 'Age', 'Fault', 'VehicleCategory', 'VehiclePrice', 'Days_Policy_Accident', 'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'PoliceReportFiled', 'WitnessPresent', 'AgentType', 'NumberOfSuppliments', 'AddressChange_Claim', 'NumberOfCars', 'Year', 'BasePolicy']
#
# [3/5] Chuẩn bị node_id và features...
#   -> Tự động sinh node_id
# ...
